# %%
# %%sql
# DROP TABLE if EXISTS config.dq_rules_config;
# CREATE TABLE config.dq_rules_config (
#     system string,
#     tier string,
#     table_name string,
#     rule_id string,
#     column_name string,
#     check_type string,
#     check_param string,
#     nullable boolean,
#     expected_type string,
#     severity string,
#     active_flag boolean,
#     create_at timestamp,
#     modified_at timestamp
# );
# Out:
# StatementMeta(, df39e2a8-2f87-4a35-a0d3-178a38b4bf9a, 3, Finished, Available, Finished, True)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# DELETE FROM config.dq_rules_config;
# INSERT INTO config.dq_rules_config
# (system, tier, table_name, rule_id, column_name,check_type, check_param, nullable, expected_type, severity, active_flag, create_at, modified_at)
#  VALUES
# ----Null and format check ---
# ('boafa', 'clean', 'transaction', 'R001', 'DUE_DATE', 'null', '', FALSE, '', 'block', TRUE, CURRENT_TIMESTAMP(), CURRENT_TIMESTAMP()),
# -----Range Check ----
# ('boafa', 'clean', 'transaction', 'R002', 'SUBSIDIARY_ID', 'range', '1,6', TRUE, 'int', 'block', TRUE, CURRENT_TIMESTAMP(), CURRENT_TIMESTAMP()),
# -----Type Check----
# ('boafa', 'clean', 'transaction', 'R003', 'TRANDATE', 'type', 'date', FALSE, 'date', 'block', TRUE, CURRENT_TIMESTAMP(), CURRENT_TIMESTAMP()),
# ----  Domain Check---
# ('boafa', 'clean', 'transaction', 'R004', 'TRANSACTION_TYPE', 'domain', 'Journal,Check,VendCred,VendBill,CustInvc', TRUE, 'string', 'block', TRUE, CURRENT_TIMESTAMP(), CURRENT_TIMESTAMP())
# Out:
# StatementMeta(, df39e2a8-2f87-4a35-a0d3-178a38b4bf9a, 5, Finished, Available, Finished, True)
# <Spark SQL result set with 1 rows and 1 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
df = spark.sql("SELECT * FROM BOAFALakehouse.config.dq_rules_config LIMIT 1000")
display(df)
# Out:
# StatementMeta(, df39e2a8-2f87-4a35-a0d3-178a38b4bf9a, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6df886c6-b655-49df-826d-3b6bfb35ec47)
