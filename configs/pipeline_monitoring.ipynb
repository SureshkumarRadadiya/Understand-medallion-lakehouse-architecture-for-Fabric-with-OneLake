# %%
# %%sql
# DROP TABLE if EXISTS config.pipeline_monitoring;
# CREATE TABLE if NOT EXISTS config.pipeline_monitoring (
#     dq_issues_count bigint,
#     duration_seconds double,
#     end_time timestamp,
#     error_message string,
#     layer_from string,
#     layer_to string,
#     pipeline_name string,
#     records_read bigint,
#     records_written bigint,
#     remarks string,
#     run_id string,
#     start_time timestamp,
#     status string,
#     system string,
#     table_name string
# );
# Out:
# StatementMeta(, 5d6b8a35-b9e3-4317-b94d-568fe2fe4c3e, 3, Finished, Available, Finished, True)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
